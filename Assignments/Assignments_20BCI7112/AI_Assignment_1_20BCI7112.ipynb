# %% [markdown]
# Creating the dataframe

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([pd.Series(np.random.rand(4)),pd.Series(np.random.rand(4)),pd.Series(np.random.rand(4)),pd.Series(np.random.rand(4))])
df
# Out:
#           0         1         2         3
# 0  0.940008  0.843398  0.693231  0.756226
# 1  0.606252  0.972684  0.022354  0.844569
# 2  0.176958  0.710357  0.257135  0.156329
# 3  0.063672  0.355597  0.810495  0.870181

# %% [markdown]
# Renaming the columns in df.

# %%
df.columns = ['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.940008        0.843398        0.693231        0.756226
# 1        0.606252        0.972684        0.022354        0.844569
# 2        0.176958        0.710357        0.257135        0.156329
# 3        0.063672        0.355597        0.810495        0.870181

# %% [markdown]
# Descriptive statistics of DF

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.446723        0.720509        0.445804        0.656826
# std          0.403436        0.265806        0.369290        0.337217
# min          0.063672        0.355597        0.022354        0.156329
# 25%          0.148637        0.621667        0.198440        0.606252
# 50%          0.391605        0.776877        0.475183        0.800397
# 75%          0.689691        0.875719        0.722547        0.850972
# max          0.940008        0.972684        0.810495        0.870181

# %%
df.describe(include='all')
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.446723        0.720509        0.445804        0.656826
# std          0.403436        0.265806        0.369290        0.337217
# min          0.063672        0.355597        0.022354        0.156329
# 25%          0.148637        0.621667        0.198440        0.606252
# 50%          0.391605        0.776877        0.475183        0.800397
# 75%          0.689691        0.875719        0.722547        0.850972
# max          0.940008        0.972684        0.810495        0.870181

# %% [markdown]
# Checking for null values

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %% [markdown]
# Display of Random value 2 & Ramdom value 3 using Location and index method

# %%
df.loc[0:,'Random value 1	':'Random value 3	']
# Out:
#    Random value 2  Random value 3
# 0        0.843398        0.693231
# 1        0.972684        0.022354
# 2        0.710357        0.257135
# 3        0.355597        0.810495

# %%
df.iloc[0:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.843398        0.693231
# 1        0.972684        0.022354
# 2        0.710357        0.257135
# 3        0.355597        0.810495
